# %%
x = 10

if x == 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다.")

# %%
x = 5

if x == 10:
    print("x에 들어있는 숫자는")
print("10입니다.")
# Out:
# 10입니다.

# %%
# 중첩 if문 사용하기

x = 15

if x >= 10:
    print("10이상입니다")

    if x == 15:
        print("15입니다")

    if x <= 20:
        print("20이하입니다")    

    if x == 20:
        print("20입니다")
# Out:
# 10이상입니다
# 15입니다
# 20이하입니다

# %%
x = int(input("숫자를 입력하세요:"))

if x == 10:
    print("10입니다")


if x == 20:
    print("20입니다")

# %%
x = 5

if x != 10:
    print("ok")
# Out:
# ok

# %%
price = int(input())
sale = input()

if sale == "Cash3000":
    print(f"{price - 3000}")
+
if sale == "Cash5000":
    print(f"{price - 5000}")
# Out:
# 67000
