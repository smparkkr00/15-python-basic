# %%
1+1
# Out:
# 2

# %%
# 주석
# 코드 실행에 영향x
# VScode에서는 단축키 ctrl + /

# %%
#1 들여쓰기
# 공백 2칸 or 4칸
# 들여쓰기 자체가 문법

# %%
# 코드블록
# 들여쓰기를 기준으로 코드 블록 구성

a = 12

if a == 12:
    print("12입니다")
# Out:
# 12입니다
