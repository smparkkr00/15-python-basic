# %%
# 불과 비교 연산자 사용하기

True
False

# %%
# 비교 연산자의 판단 결과
3 > 1
# Out:
# True

# %%
# 숫자 같은지 비교
10 == 10
# Out:
# True

# %%
print("Python" == "Python")
print("Python" == "python")
print("Python" != "python")
# Out:
# True
# False
# True

# %%
# 부등호 사용하기


print(10 > 20)
print(10 < 20)
print(10 <= 20)
print(10 >= 20)
# Out:
# False
# True
# True
# False

# %%
# 객체가 같은지 다른지 비교하기

print(1 == 1.0)
print(1 is 1.0)
# Out:
# True
# False
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDT34\AppData\Local\Temp\ipykernel_29640\3916754254.py:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\KDT34\AppData\Local\Temp\ipykernel_29640\2095918375.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
# 논리 연산자 사용하기(and)

print(True and True)
print(False and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
# or연산자

print(True  or True)
print(False or  True)
print(True  or False)
print(False or  False)
# Out:
# True
# True
# True
# False

# %%
not True and False or not False
#(((not True) and False) or (not False))
# Out:
# True

# %%
# 논리 연산자, 비교 연산자 사용

print(10 == 10 and 10 != 5)

print(10 > 5 or 10 < 5)

print((not 10) < 5)

print(not 1 is 1.0)
# Out:
# True
# True
# True
# True
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDT34\AppData\Local\Temp\ipykernel_29640\2386789228.py:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
korean, english, math, science = 92, 47, 86, 81

print(korean >= 50 and english >= 50 and math >= 50 and science >= 50)
# Out:
# False

# %%
kor, eng, math, sicence = map(int, input().split(" "))

print(kor >= 90 and eng > 80 and math > 85 and science >= 80)
# Out:
# False
