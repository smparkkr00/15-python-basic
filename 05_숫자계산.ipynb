# %%
#사칙연산

print(1 + 1)
print(1 - 1)
print(2 * 2)
print(4 / 2)
# Out:
# 2
# 4

# %%
#나눗셈 후 소수점이하를 버리는 // 연산자

# %%
# 나머지 연산자(%)
5 % 2
# Out:
# 1

# %%
# 거듭제곱 연산자(**)

print(2 ** 10)

print(10000 ** 0.5)
# Out:
# 1024
# 100.0

# %%
# 값을 정수로 만들기

print(int(3.3))
print(int(4 / 2))
# Out:
# 3
# 2

# %%
# 객체의 자료형을 예상하는 함수
type(10)
# Out:
# int

# %%
# 2진수
print(0b110)
print((1 * 2 ** 2) + (1 * 2) + (0 * 1))
print(0b111111)
# Out:
# 6
# 6
# 63

# %%
# 8진수
print(0o110)
print((1 * 8 ** 2) + (1 * 8) + (1 * 0))
# Out:
# 72
# 72

# %%
# 16진수
print(0xAF)
(10 * 16 ** 1) + (15 * 16 ** 0)
# Out:
# 175
# 175

# %%
# 실수 계산하기

3.5 + 2.1
# Out:
# 5.6

# %%
# 값을 실수로 만들기(float)
print(float(5))
print(float())
print(float("5.3"))
#float("hi") -> 오류
# Out:
# 5.0
# 0.0
# 5.3

# %%
# 괄호 사용하기
print
